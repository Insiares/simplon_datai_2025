# %% [markdown]
# # Test ouvrir un csv avec pandas

# %%
import pandas as pd 

#pd.read_csv()

#corr
#heatmap

# %%
#un exemple de heatmap
#index des lignes
idx = ['1', '2', '3', '4']
#noms des colonnes
cols = list('ABCD')

#création du dataframe
df = pd.DataFrame([[10, 20, 30, 40], [50, 30, 8, 15],
                   [25, 14, 41, 8], [7, 14, 21, 28]],
                   columns = cols, index = idx)

#correlation : 
corr = df.corr()
corr
# Out:
#           A         B         C         D
# A  1.000000  0.795520 -0.519566 -0.654733
# B  0.795520  1.000000 -0.764484 -0.063854
# C -0.519566 -0.764484  1.000000 -0.065622
# D -0.654733 -0.063854 -0.065622  1.000000

# %%
#pour colorier le dataframe : 
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d0ca4_row0_col0, #T_d0ca4_row1_col1, #T_d0ca4_row2_col2, #T_d0ca4_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d0ca4_row0_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_d0ca4_row0_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_d0ca4_row0_col3, #T_d0ca4_row1_col2, #T_d0ca4_row2_col1, #T_d0ca4_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d0ca4_row1_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_d0ca4_row1_col3, #T_d0ca4_row2_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_d0ca4_row2_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d0ca4_row3_col1, #T_d0ca4_row3_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# </style>
# <table id="T_d0ca4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0ca4_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d0ca4_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_d0ca4_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_d0ca4_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0ca4_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_d0ca4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d0ca4_row0_col1" class="data row0 col1" >0.795520</td>
#       <td id="T_d0ca4_row0_col2" class="data row0 col2" >-0.519566</td>
#       <td id="T_d0ca4_row0_col3" class="data row0 col3" >-0.654733</td>
#     </tr>
#     <tr>
#       <th id="T_d0ca4_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_d0ca4_row1_col0" class="data row1 col0" >0.795520</td>
#       <td id="T_d0ca4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d0ca4_row1_col2" class="data row1 col2" >-0.764484</td>
#       <td id="T_d0ca4_row1_col3" class="data row1 col3" >-0.063854</td>
#     </tr>
#     <tr>
#       <th id="T_d0ca4_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_d0ca4_row2_col0" class="data row2 col0" >-0.519566</td>
#       <td id="T_d0ca4_row2_col1" class="data row2 col1" >-0.764484</td>
#       <td id="T_d0ca4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d0ca4_row2_col3" class="data row2 col3" >-0.065622</td>
#     </tr>
#     <tr>
#       <th id="T_d0ca4_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_d0ca4_row3_col0" class="data row3 col0" >-0.654733</td>
#       <td id="T_d0ca4_row3_col1" class="data row3 col1" >-0.063854</td>
#       <td id="T_d0ca4_row3_col2" class="data row3 col2" >-0.065622</td>
#       <td id="T_d0ca4_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Out:
#   index   A   B   C   D
# 0     1  10  20  30  40
# 1     2  50  30   8  15
# 2     3  25  14  41   8
# 3     4   7  14  21  28
