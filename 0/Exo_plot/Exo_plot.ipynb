# %% [markdown]
# ## Exo pyplot

# %% [markdown]
# Tracer un graphe linéaire des points (x, y) où x = [0, 1, 2, 3, 4] et y = [1, 4, 3, 8, 5].

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0, 1, 2, 3, 4]
y = [1, 4, 3, 8, 5]

plt.plot(x,y, 'r-')
plt.ylabel("y")
plt.xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# Tracer un histogramme à partir de données aléatoires générées par NumPy.

# %%
val = np.random.randn(50000) *10
plt.hist(val, bins=100, density=True)
# Out:
# (array([2.36096662e-05, 0.00000000e+00, 2.36096662e-05, 2.36096662e-05,
#         4.72193323e-05, 4.72193323e-05, 9.44386646e-05, 7.08289985e-05,
#         4.72193323e-05, 1.65267663e-04, 3.30535326e-04, 9.44386646e-05,
#         2.59706328e-04, 4.72193323e-04, 4.01364325e-04, 5.43022322e-04,
#         7.08289985e-04, 8.97167314e-04, 1.20409297e-03, 1.39297030e-03,
#         1.65267663e-03, 2.07765062e-03, 2.76233094e-03, 3.65949825e-03,
#         4.13169158e-03, 4.81637190e-03, 5.87880687e-03, 6.13851320e-03,
#         7.43704484e-03, 8.26338315e-03, 1.05535208e-02, 1.13798591e-02,
#         1.31741937e-02, 1.54171120e-02, 1.72114466e-02, 1.89113426e-02,
#         2.08709449e-02, 2.28777665e-02, 2.50262461e-02, 2.57109264e-02,
#         2.83552091e-02, 3.18494396e-02, 3.17077816e-02, 3.41631869e-02,
#         3.50839639e-02, 3.74921499e-02, 3.81060012e-02, 4.08683321e-02,
#         3.91212168e-02, 3.83893172e-02, 3.85545848e-02, 4.13405254e-02,
#         3.69019082e-02, 3.79407335e-02, 3.72324435e-02, 3.45173319e-02,
#         3.40215289e-02, 3.07870047e-02, 2.86385250e-02, 3.10703207e-02,
#         2.73872127e-02, 2.51442945e-02, 2.29485955e-02, 2.14139672e-02,
#         1.82502719e-02, 1.77308593e-02, 1.52282347e-02, 1.27020004e-02,
#         1.19228814e-02, 1.08604464e-02, 9.13694080e-03, 8.12172516e-03,
#         6.82319352e-03, 5.50105221e-03, 5.38300388e-03, 4.41500757e-03,
#         3.09286627e-03, 2.85676960e-03, 2.12486995e-03, 1.91238296e-03,
#         1.67628630e-03, 1.20409297e-03, 8.26338315e-04, 6.84680318e-04,
#         4.01364325e-04, 3.06925660e-04, 3.30535326e-04, 2.83315994e-04,
#         1.41657997e-04, 2.12486995e-04, 2.12486995e-04, 9.44386646e-05,
#         7.08289985e-05, 0.00000000e+00, 2.36096662e-05, 2.36096662e-05,
#         2.36096662e-05, 2.36096662e-05, 0.00000000e+00, 4.72193323e-05]),
#  array([-4.23428481e+01, -4.14957374e+01, -4.06486268e+01, -3.98015161e+01,
#         -3.89544054e+01, -3.81072948e+01, -3.72601841e+01, -3.64130734e+01,
#         -3.55659628e+01, -3.47188521e+01, -3.38717414e+01, -3.30246308e+01,
#         -3.21775201e+01, -3.13304094e+01, -3.04832988e+01, -2.96361881e+01,
#         -2.87890774e+01, -2.79419668e+01, -2.70948561e+01, -2.62477454e+01,
#         -2.54006348e+01, -2.45535241e+01, -2.37064135e+01, -2.28593028e+01,
#         -2.20121921e+01, -2.11650815e+01, -2.03179708e+01, -1.94708601e+01,
#         -1.86237495e+01, -1.77766388e+01, -1.69295281e+01, -1.60824175e+01,
#         -1.52353068e+01, -1.43881961e+01, -1.35410855e+01, -1.26939748e+01,
#         -1.18468641e+01, -1.09997535e+01, -1.01526428e+01, -9.30553214e+00,
#         -8.45842148e+00, -7.61131081e+00, -6.76420015e+00, -5.91708948e+00,
#         -5.06997882e+00, -4.22286815e+00, -3.37575749e+00, -2.52864682e+00,
#         -1.68153616e+00, -8.34425493e-01,  1.26851719e-02,  8.59795837e-01,
#          1.70690650e+00,  2.55401717e+00,  3.40112783e+00,  4.24823850e+00,
#          5.09534916e+00,  5.94245983e+00,  6.78957049e+00,  7.63668116e+00,
#          8.48379182e+00,  9.33090249e+00,  1.01780132e+01,  1.10251238e+01,
#          1.18722345e+01,  1.27193451e+01,  1.35664558e+01,  1.44135665e+01,
#          1.52606771e+01,  1.61077878e+01,  1.69548985e+01,  1.78020091e+01,
#          1.86491198e+01,  1.94962305e+01,  2.03433411e+01,  2.11904518e+01,
#          2.20375625e+01,  2.28846731e+01,  2.37317838e+01,  2.45788945e+01,
#          2.54260051e+01,  2.62731158e+01,  2.71202265e+01,  2.79673371e+01,
#          2.88144478e+01,  2.96615585e+01,  3.05086691e+01,  3.13557798e+01,
#          3.22028904e+01,  3.30500011e+01,  3.38971118e+01,  3.47442224e+01,
#          3.55913331e+01,  3.64384438e+01,  3.72855544e+01,  3.81326651e+01,
#          3.89797758e+01,  3.98268864e+01,  4.06739971e+01,  4.15211078e+01,
#          4.23682184e+01]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# Tracer un diagramme à barres à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D', 'E'], valeurs = [25, 30, 15, 20, 10]
#
# Tracer un nuage de points à partir de données aléatoires générées par NumPy.
#
# Tracer une courbe sinusoïdale en utilisant NumPy.
#
# Tracer deux courbes sur le même graphe à partir des données suivantes :
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)
#
# Tracer un diagramme en secteurs (camembert) à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D'], valeurs = [30, 25, 15, 20]
#
# Tracer une courbe polynomiale à partir des données suivantes :
# x = np.linspace(-5, 5, 100)
# y = 3 * x**3 + 2 * x**2 - 8 * x + 5
#
# Tracer un diagramme en barres empilées à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D']
# valeurs1 = [10, 15, 20, 25], valeurs2 = [5, 10, 15, 20]
#
# Tracer un graphique en boîte (boxplot) à partir des données suivantes :
# data = [np.random.normal(0, 1, 100), np.random.normal(2, 1, 100), np.random.normal(-3, 2, 100)]

# %% [markdown]
# ## 9
# Tracer un graphique en boîte (boxplot) à partir des données suivantes :
# data = [np.random.normal(0, 1, 100), np.random.normal(2, 1, 100), np.random.normal(-3, 2, 100)]

# %%
data = [np.random.normal(0, 1, 100), 
        np.random.normal(2, 1, 100), 
        np.random.normal(-3, 2, 100)]
plt.boxplot(data, 
            notch=False, 
            sym="bo", 
            vert=False, 
            whis=1.5, 
            labels=['set 1',' set 2',' set 3'], 
            meanline=True)
plt.title('Boxplot')
plt.xlabel('Valeurs observées')
plt.ylabel('3 jeux de données différents')
plt.grid()

# %%
#Boxblot en OO avec couleur ! 
fig, (graph1) = plt.subplots()
graph1.set_title('Boxplot en couleur!')
ma_joli_box = graph1.boxplot(data, 
                             notch=True, 
                             sym="o", 
                             vert=False, 
                             labels=['set 1',' set 2',' set 3'],
                             patch_artist=True)


colors = ['pink', 'lightblue', 'lightgreen']
for patch, color in zip(ma_joli_box['boxes'], colors):
    patch.set_facecolor(color)
    
graph1.xaxis.grid()
graph1.set_xlabel('Valeurs observées')
graph1.set_ylabel('3 jeux de données différents')

plt.show()
