# %% [markdown]
# ## Exo pyplot

# %% [markdown]
# Tracer un graphe linéaire des points (x, y) où x = [0, 1, 2, 3, 4] et y = [1, 4, 3, 8, 5].

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0, 1, 2, 3, 4]
y = [1, 4, 3, 8, 5]

plt.plot(x,y, 'r-')
plt.ylabel("y")
plt.xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# Tracer un histogramme à partir de données aléatoires générées par NumPy.

# %%
val = np.random.randn(50000) *10
plt.hist(val, bins=100, density=True)
# Out:
# (array([4.88966109e-05, 0.00000000e+00, 0.00000000e+00, 9.77932217e-05,
#         4.88966109e-05, 4.88966109e-05, 7.33449163e-05, 1.46689833e-04,
#         1.22241527e-04, 2.68931360e-04, 3.91172887e-04, 3.66724581e-04,
#         3.91172887e-04, 5.37862719e-04, 6.60104247e-04, 9.53483912e-04,
#         1.14907036e-03, 1.63803646e-03, 2.07810596e-03, 2.46927885e-03,
#         2.34703732e-03, 3.71614242e-03, 3.78948734e-03, 4.37624667e-03,
#         5.59866194e-03, 5.72090347e-03, 6.55214585e-03, 8.16573401e-03,
#         9.82821878e-03, 1.15640485e-02, 1.24930841e-02, 1.30309468e-02,
#         1.52557426e-02, 1.82873325e-02, 1.93141613e-02, 2.22479579e-02,
#         2.32014418e-02, 2.55484792e-02, 2.73576538e-02, 2.98269326e-02,
#         3.13427276e-02, 3.34941784e-02, 3.54500429e-02, 3.48388352e-02,
#         3.52789047e-02, 3.94840133e-02, 3.96062548e-02, 3.97773929e-02,
#         3.82615980e-02, 4.07797735e-02, 3.95084616e-02, 3.82860463e-02,
#         3.80904599e-02, 3.88239090e-02, 3.53278013e-02, 3.50344217e-02,
#         3.32252471e-02, 3.04625886e-02, 3.09026581e-02, 2.67464461e-02,
#         2.61841351e-02, 2.30792003e-02, 2.18567851e-02, 2.10255427e-02,
#         1.74560901e-02, 1.47423282e-02, 1.58669502e-02, 1.27620154e-02,
#         1.21263595e-02, 1.00238052e-02, 8.45911368e-03, 6.99221535e-03,
#         6.57659416e-03, 5.45197211e-03, 4.96300600e-03, 3.59390090e-03,
#         3.22717632e-03, 2.68931360e-03, 2.12700257e-03, 1.80917460e-03,
#         1.34465680e-03, 9.53483912e-04, 1.02682883e-03, 9.53483912e-04,
#         4.88966109e-04, 5.13414414e-04, 2.93379665e-04, 3.91172887e-04,
#         1.95586443e-04, 2.20034749e-04, 2.44483054e-04, 1.46689833e-04,
#         2.44483054e-05, 0.00000000e+00, 2.44483054e-05, 2.44483054e-05,
#         2.44483054e-05, 0.00000000e+00, 7.33449163e-05, 2.44483054e-05]),
#  array([-4.00859125e+01, -3.92678599e+01, -3.84498073e+01, -3.76317547e+01,
#         -3.68137021e+01, -3.59956495e+01, -3.51775968e+01, -3.43595442e+01,
#         -3.35414916e+01, -3.27234390e+01, -3.19053864e+01, -3.10873338e+01,
#         -3.02692812e+01, -2.94512286e+01, -2.86331760e+01, -2.78151234e+01,
#         -2.69970708e+01, -2.61790182e+01, -2.53609656e+01, -2.45429130e+01,
#         -2.37248603e+01, -2.29068077e+01, -2.20887551e+01, -2.12707025e+01,
#         -2.04526499e+01, -1.96345973e+01, -1.88165447e+01, -1.79984921e+01,
#         -1.71804395e+01, -1.63623869e+01, -1.55443343e+01, -1.47262817e+01,
#         -1.39082291e+01, -1.30901764e+01, -1.22721238e+01, -1.14540712e+01,
#         -1.06360186e+01, -9.81796602e+00, -8.99991341e+00, -8.18186080e+00,
#         -7.36380820e+00, -6.54575559e+00, -5.72770298e+00, -4.90965037e+00,
#         -4.09159777e+00, -3.27354516e+00, -2.45549255e+00, -1.63743994e+00,
#         -8.19387338e-01, -1.33473020e-03,  8.16717877e-01,  1.63477048e+00,
#          2.45282309e+00,  3.27087570e+00,  4.08892831e+00,  4.90698091e+00,
#          5.72503352e+00,  6.54308613e+00,  7.36113874e+00,  8.17919134e+00,
#          8.99724395e+00,  9.81529656e+00,  1.06333492e+01,  1.14514018e+01,
#          1.22694544e+01,  1.30875070e+01,  1.39055596e+01,  1.47236122e+01,
#          1.55416648e+01,  1.63597174e+01,  1.71777700e+01,  1.79958226e+01,
#          1.88138752e+01,  1.96319278e+01,  2.04499805e+01,  2.12680331e+01,
#          2.20860857e+01,  2.29041383e+01,  2.37221909e+01,  2.45402435e+01,
#          2.53582961e+01,  2.61763487e+01,  2.69944013e+01,  2.78124539e+01,
#          2.86305065e+01,  2.94485591e+01,  3.02666117e+01,  3.10846644e+01,
#          3.19027170e+01,  3.27207696e+01,  3.35388222e+01,  3.43568748e+01,
#          3.51749274e+01,  3.59929800e+01,  3.68110326e+01,  3.76290852e+01,
#          3.84471378e+01,  3.92651904e+01,  4.00832430e+01,  4.09012956e+01,
#          4.17193482e+01]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# Tracer un diagramme à barres à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D', 'E'], valeurs = [25, 30, 15, 20, 10]
#
# Tracer un nuage de points à partir de données aléatoires générées par NumPy.
#
# Tracer une courbe sinusoïdale en utilisant NumPy.
#
# Tracer deux courbes sur le même graphe à partir des données suivantes :
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)
#
# Tracer un diagramme en secteurs (camembert) à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D'], valeurs = [30, 25, 15, 20]
#
# Tracer une courbe polynomiale à partir des données suivantes :
# x = np.linspace(-5, 5, 100)
# y = 3 * x**3 + 2 * x**2 - 8 * x + 5
#
# Tracer un diagramme en barres empilées à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D']
# valeurs1 = [10, 15, 20, 25], valeurs2 = [5, 10, 15, 20]
#
# Tracer un graphique en boîte (boxplot) à partir des données suivantes :
# data = [np.random.normal(0, 1, 100), np.random.normal(2, 1, 100), np.random.normal(-3, 2, 100)]

# %% [markdown]
# ## 9
# Tracer un graphique en boîte (boxplot) à partir des données suivantes :
# data = [np.random.normal(0, 1, 100), np.random.normal(2, 1, 100), np.random.normal(-3, 2, 100)]

# %%
data = [np.random.normal(0, 1, 100), 
        np.random.normal(2, 1, 100), 
        np.random.normal(-3, 2, 100)]
plt.boxplot(data, 
            notch=False, 
            sym="bo", 
            vert=False, 
            whis=1.5, 
            labels=['set 1',' set 2',' set 3'], 
            meanline=True)
plt.title('Boxplot')
plt.xlabel('Valeurs observées')
plt.ylabel('3 jeux de données différents')
plt.grid()

# %%
#Boxblot en OO avec couleur ! 
fig, (graph1) = plt.subplots()
graph1.set_title('Boxplot en couleur!')
ma_joli_box = graph1.boxplot(data, 
                             notch=True, 
                             sym="o", 
                             vert=False, 
                             labels=['set 1',' set 2',' set 3'],
                             patch_artist=True)


colors = ['pink', 'lightblue', 'lightgreen']
for patch, color in zip(ma_joli_box['boxes'], colors):
    patch.set_facecolor(color)
    
graph1.xaxis.grid()
graph1.set_xlabel('Valeurs observées')
graph1.set_ylabel('3 jeux de données différents')

plt.show()

# %% [markdown]
# ## 10
# Tracer un nuage de points à partir de données aléatoires générées par NumPy.

# %%
#création des points avec (x,y) aléatoires
data_x = np.random.normal(0,10, 100)
data_y = np.random.normal(0,10,100)
data_z = np.random.normal(0,100,100)
data_quatro= np.random.normal(0,100,100)
plt.scatter(data_x,
            data_y,
            s = data_quatro, #taille des points (arraylike si variable)
            c = data_z, #couleur des points
            marker = "P", #marker std matplotlib: https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers
            cmap ='viridis',   #colormap function ou str pour appel
            # norm = 'linear', #une normalisation pour la colormap
            alpha=0.5, #self_explanatory, transparence des points en cas de superposition, float entre 0 et 1
            linewidths=1,  #épaisseur des bords des marqueurs (1.5 par défaut)
            edgecolors='black', #couleurs des bords des marqueurs (face, none, ou une sequence de couleurs)
            plotnonfinite=False #bool, s'il faut tracer les points non définis (NaN ou inf)

            )

# %%
#Scatter + Histo avec un set aléatoire , en OO

#délimiter la figure
fig = plt.figure(figsize=(6,6))

''' on va définir un "gridspec" de 2x2 (on a trois graph dans un tableau et une case vide)
il est possible de définir le ratio des axes selon les besoins, voir les params de la méthode addgridspec'''
my_grid = fig.add_gridspec(2, 2, #taille de la maille
                           width_ratios = (4, 1),
                           height_ratios = (1, 4),#ratio des axes
                            # left = 0.2,
                            # right = 0.8, 
                            # bottom = 0.2,
                            # top = 0.8, #fractions de la figure d'origine, jouer avec pour voir, left > right, top > bottom, marges avec le bord
                            wspace = 0.2,
                            hspace = 0.2, #marges entre les graphes
                           )

#création des axes

axe = fig.add_subplot(my_grid[1,0]) # premier graph (scatter), dans la seconde ligne premier colonne du gridspec
axe_histx = fig.add_subplot(my_grid[0,0], sharex = axe) #etc 
axe_histy = fig.add_subplot(my_grid[1,1], sharey = axe)

#on trace le scatter
axe.scatter(data_x, data_y)
#on ajoute les histo
axe_histx.hist(data_x, bins = 50, density= True)
axe_histy.hist(data_y, bins = 50, density = True, orientation='horizontal')
# les abcisses des histos sont redondantes, on peut les enlever : 
axe_histx.tick_params(axis='x', labelbottom = False)
axe_histy.tick_params(axis='y', labelleft = False)

# %%
#si on essaie de rajouter une catégorie à deux jeux de données : 
import matplotlib
data_triple = np.random.randn(100,2)
couleurs = np.random.randint(0,2, 100)
fig = plt.figure(figsize=(6,6))

my_grid = fig.add_gridspec(2, 2, 
                           width_ratios = (4, 1),
                           height_ratios = (1, 4),
                            wspace = 0.2,
                            hspace = 0.2,
                           )

axe = fig.add_subplot(my_grid[1,0]) 
axe_histx = fig.add_subplot(my_grid[0,0], sharex = axe) 
axe_histy = fig.add_subplot(my_grid[1,1], sharey = axe)

#pour colorier le scatter et les histo de la même façon
type_couleur= [matplotlib.cm.Accent(0) , matplotlib.cm.Accent(1)]

axe.scatter(x= data_triple[:,0], y= data_triple[:,1], c= couleurs, cmap = 'Accent')

axe_histx.hist(data_triple , color = type_couleur, bins = 50, density= True)
axe_histy.hist(data_triple , color = type_couleur, bins = 50, density = True, orientation='horizontal')

axe_histx.tick_params(axis='x', labelbottom = False)
axe_histy.tick_params(axis='y', labelleft = False)
