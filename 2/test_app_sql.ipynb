# %%
import pymysql.cursors
# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             database='floconschema',
                             cursorclass=pymysql.cursors.DictCursor)

with connection:
    with connection.cursor() as cursor:
        # Read a single record
        sql = "SELECT * FROM `table_ini` "
        cursor.execute(sql)
        result = cursor.fetchall()
        print(result)
# Out:
# [{'id': 1, 'name': 'Isabelle Knapp', 'address': '879-7845 Duis St.', 'city': 'Dutse', 'country': 'United Kingdom', 'currency': 'kwacha'}, {'id': 2, 'name': 'Cameron Hughes', 'address': '767-3962 Fringilla, St.', 'city': 'Jiangsu', 'country': 'Indonesia', 'currency': 'peso'}, {'id': 3, 'name': 'Emi Hardy', 'address': '3422 Scelerisque Av.', 'city': 'Neunkirchen', 'country': 'Nigeria', 'currency': 'dram'}, {'id': 4, 'name': 'Abbot Baxter', 'address': '814-3295 A Rd.', 'city': 'Bedok', 'country': 'Peru', 'currency': 'euro'}, {'id': 5, 'name': 'Cathleen May', 'address': 'Ap #871-3629 Tincidunt St.', 'city': 'Butuan', 'country': 'Norway', 'currency': 'dirham'}, {'id': 6, 'name': 'Jarrod Garrett', 'address': '2270 Lectus Road', 'city': 'Agartala', 'country': 'Pakistan', 'currency': 'lek'}, {'id': 7, 'name': 'Lilah Gross', 'address': '3584 Lacus. Ave', 'city': 'LiŽge', 'country': 'Philippines', 'currency': 'pound'}, {'id': 8, 'name': 'Anne Gamble', 'address': '475-1428 Non Ave', 'city': 'Kieldrecht', 'country': 'Vietnam', 'currency': 'somoni'}, {'id': 9, 'name': 'Francis Acevedo', 'address': 'Ap #863-8129 Maecenas Road', 'city': 'North Waziristan', 'country': 'Sweden', 'currency': 'Danish krone'}, {'id': 10, 'name': 'Maite Crane', 'address': '551-4392 Nibh. Road', 'city': 'Norrköping', 'country': 'South Korea', 'currency': 'tugrik'}, {'id': 11, 'name': 'Jessamine Hendricks', 'address': '5289 At St.', 'city': 'Ipswich', 'country': 'Costa Rica', 'currency': 'cedi'}, {'id': 12, 'name': 'Flynn Huffman', 'address': '475-5596 Morbi St.', 'city': 'Limoges', 'country': 'Turkey', 'currency': 'shilling'}, {'id': 13, 'name': 'Yasir Rodriquez', 'address': 'P.O. Box 615, 2795 In Avenue', 'city': 'Wals-Siezenheim', 'country': 'Ireland', 'currency': 'denar'}, {'id': 14, 'name': 'Tarik Mendez', 'address': 'P.O. Box 325, 4079 Viverra. St.', 'city': 'Sicuani', 'country': 'Singapore', 'currency': 'lek'}, {'id': 15, 'name': 'Perry Waller', 'address': '9444 Faucibus Street', 'city': 'Belfast', 'country': 'South Africa', 'currency': 'zloty'}, {'id': 16, 'name': 'Luke Mcbride', 'address': 'Ap #654-4800 Senectus St.', 'city': 'Muzaffargarh', 'country': 'New Zealand', 'currency': 'rial'}, {'id': 17, 'name': 'Jermaine Lancaster', 'address': 'Ap #512-1856 Dictum Rd.', 'city': 'Recife', 'country': 'New Zealand', 'currency': 'real'}, {'id': 18, 'name': 'Kareem Haney', 'address': '398-8898 Suspendisse St.', 'city': 'Gary', 'country': 'Colombia', 'currency': 'krona'}, {'id': 19, 'name': 'Deacon Rosario', 'address': 'Ap #770-8212 Sed St.', 'city': 'Dornbirn', 'country': 'Austria', 'currency': 'riel'}, {'id': 20, 'name': 'Ignacia England', 'address': 'Ap #844-7360 Nonummy. St.', 'city': 'Lima', 'country': 'Peru', 'currency': 'som'}, {'id': 21, 'name': 'Natalie Finley', 'address': 'Ap #865-2264 Blandit St.', 'city': 'Villers-le-Peuplier', 'country': 'Germany', 'currency': 'rupiah'}, {'id': 22, 'name': 'Travis Howe', 'address': '303-2983 Tortor. Ave', 'city': 'Antibes', 'country': 'Chile', 'currency': 'yuan'}, {'id': 23, 'name': 'Zachery Fulton', 'address': '394-8966 Nunc Avenue', 'city': 'Laives/Leifers', 'country': 'New Zealand', 'currency': 'hryvnia'}, {'id': 24, 'name': 'Fleur Houston', 'address': 'Ap #473-9804 Euismod Road', 'city': 'Hengelo', 'country': 'Australia', 'currency': 'zloty'}, {'id': 25, 'name': 'Keely Dean', 'address': '990-5102 Dictum Ave', 'city': 'Jeju', 'country': 'United Kingdom', 'currency': 'shekel'}, {'id': 26, 'name': 'Nevada Crane', 'address': '706-6256 Donec Rd.', 'city': 'Cusco', 'country': 'Nigeria', 'currency': 'ruble'}, {'id': 27, 'name': 'Rosalyn Hicks', 'address': '7796 Et St.', 'city': 'Municipal District', 'country': 'Sweden', 'currency': 'ariary'}, {'id': 28, 'name': 'Kasimir Knapp', 'address': '659-6218 Tellus St.', 'city': 'Loupoigne', 'country': 'South Korea', 'currency': 'konvertibilna marka'}, {'id': 29, 'name': 'Kerry Herring', 'address': 'Ap #792-5377 Penatibus Rd.', 'city': 'Jackson', 'country': 'Italy', 'currency': 'kwach ...
