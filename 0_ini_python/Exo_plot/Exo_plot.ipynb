# %% [markdown]
# ## Exo pyplot

# %% [markdown]
# Tracer un graphe linéaire des points (x, y) où x = [0, 1, 2, 3, 4] et y = [1, 4, 3, 8, 5].

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0, 1, 2, 3, 4]
y = [1, 4, 3, 8, 5]

plt.plot(x,y, 'r-')
plt.ylabel("y")
plt.xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# Tracer un histogramme à partir de données aléatoires générées par NumPy.

# %%
val = np.random.randn(50000) *10
plt.hist(val, bins=100, density=True,)
# Out:
# (array([7.10817668e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.36939223e-05, 4.73878445e-05, 2.36939223e-05, 4.73878445e-05,
#         4.73878445e-05, 1.18469611e-04, 1.65857456e-04, 1.89551378e-04,
#         3.08020989e-04, 2.60633145e-04, 3.55408834e-04, 5.21266290e-04,
#         5.44960212e-04, 8.05593357e-04, 5.92348056e-04, 8.52981201e-04,
#         1.61118671e-03, 1.61118671e-03, 2.36939223e-03, 2.86696459e-03,
#         3.48300657e-03, 3.76733364e-03, 4.47815131e-03, 5.59176565e-03,
#         6.87123745e-03, 7.39250374e-03, 9.54865067e-03, 1.03779379e-02,
#         1.17047976e-02, 1.43822108e-02, 1.54484373e-02, 1.75571964e-02,
#         1.85523411e-02, 1.98555068e-02, 2.36702283e-02, 2.54472725e-02,
#         2.76981951e-02, 2.99017299e-02, 3.11101199e-02, 3.38586149e-02,
#         3.35269000e-02, 3.66544977e-02, 3.77918060e-02, 3.90475839e-02,
#         4.01848921e-02, 3.92608292e-02, 3.95925441e-02, 4.00427286e-02,
# ...

# %% [markdown]
# Tracer un diagramme à barres à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D', 'E'], valeurs = [25, 30, 15, 20, 10]

# %%
categories = ['A', 'B', 'C', 'D', 'E']
valeurs = [25, 30, 15, 20, 10]

plt.bar(x = categories, #abcisses
        height = valeurs , #ordonnées
        width = 0.8, #largeur des barres
        bottom = 0.5, #off du bas des barres
        align = 'edge', #alignement sur x des barres
        color = 'red', 
        edgecolor = 'blue',
        linewidth = 5, #largeur du edge
        
        )
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Tracer un diagramme en barres empilées à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D']
# valeurs1 = [10, 15, 20, 25], valeurs2 = [5, 10, 15, 20]

# %%
categories = ['A', 'B', 'C', 'D']
valeurs1 = [10, 15, 20, 25]
valeurs2 = [5, 10, 15, 20]

plt.bar(x= categories,
        height= valeurs1,
        label = 'valeurs1')
plt.bar(x= categories,
        height= valeurs2,
        bottom= valeurs1,
        label = 'valeurs2')
plt.legend()

# %% [markdown]
# Tracer une courbe sinusoïdale en utilisant NumPy.

# %%
x = 3*np.linspace(0, 2*np.pi)
sin = np.sin(x)
plt.plot(x, sin)

# %% [markdown]
# Tracer deux courbes sur le même graphe à partir des données suivantes :
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1, label = 'y1')
plt.plot(x, y2, label = 'y2')
plt.legend()

# %% [markdown]
# Tracer un diagramme en secteurs (camembert) à partir des données suivantes :
# categories = ['A', 'B', 'C', 'D'], valeurs = [30, 25, 15, 20]

# %%
categories = ['A', 'B', 'C', 'D']
valeurs = [30, 25, 15, 20]
expl = [0.001*y for y in valeurs]
plt.pie(x=valeurs, #taille des pieces
        explode = expl, #list de valeurs de même longueur que x 
        labels = categories, #étiquettes
        colors = None, #liste de couleurs
        shadow = True,
        radius = 0.9, 
        )
# Out:
# ([<matplotlib.patches.Wedge at 0x25dbc1bbd60>,
# ...
#  [Text(0.5099999724317289, 0.8833459277766756, 'A'),
#   Text(-0.9995798876429275, 0.17625279634590965, 'B'),
#   Text(-0.34373009176293084, -0.9443911393149808, 'C'),
#   Text(0.7737050057411504, -0.6492153449288507, 'D')])

# %% [markdown]
# Tracer une courbe polynomiale à partir des données suivantes :
# x = np.linspace(-5, 5, 100)
# y = 3 * x**3 + 2 * x**2 - 8 * x + 5

# %%
x = np.linspace(-5, 5, 100)
y = 3 * x**3 + 2 * x**2 - 8 * x + 5

plt.plot(x,y)

# %% [markdown]
# ## 9
# Tracer un graphique en boîte (boxplot) à partir des données suivantes :
# data = [np.random.normal(0, 1, 100), np.random.normal(2, 1, 100), np.random.normal(-3, 2, 100)]

# %%
data = [np.random.normal(0, 1, 100), 
        np.random.normal(2, 1, 100), 
        np.random.normal(-3, 2, 100)]
plt.boxplot(data, 
            notch=False, 
            sym="bo", 
            vert=False, 
            whis=1.5, 
            labels=['set 1',' set 2',' set 3'], 
            meanline=True)
plt.title('Boxplot')
plt.xlabel('Valeurs observées')
plt.ylabel('3 jeux de données différents')
plt.grid()

# %%
#Boxblot en OO avec couleur ! 
fig, (graph1) = plt.subplots()
graph1.set_title('Boxplot en couleur!')
ma_joli_box = graph1.boxplot(data, 
                             notch=True, 
                             sym="o", 
                             vert=False, 
                             labels=['set 1',' set 2',' set 3'],
                             patch_artist=True)


colors = ['pink', 'lightblue', 'lightgreen']
for patch, color in zip(ma_joli_box['boxes'], colors):
    patch.set_facecolor(color)
    
graph1.xaxis.grid()
graph1.set_xlabel('Valeurs observées')
graph1.set_ylabel('3 jeux de données différents')

plt.show()

# %% [markdown]
# ## 10
# Tracer un nuage de points à partir de données aléatoires générées par NumPy.

# %%
#création des points avec (x,y) aléatoires
data_x = np.random.normal(0,10, 100)
data_y = np.random.normal(0,10,100)
data_z = np.random.normal(0,100,100)
data_quatro= np.random.normal(0,100,100)
plt.scatter(data_x,
            data_y,
            s = data_quatro, #taille des points (arraylike si variable)
            c = data_z, #couleur des points
            marker = "P", #marker std matplotlib: https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers
            cmap ='viridis',   #colormap function ou str pour appel
            # norm = 'linear', #une normalisation pour la colormap
            alpha=0.5, #self_explanatory, transparence des points en cas de superposition, float entre 0 et 1
            linewidths=1,  #épaisseur des bords des marqueurs (1.5 par défaut)
            edgecolors='black', #couleurs des bords des marqueurs (face, none, ou une sequence de couleurs)
            plotnonfinite=False #bool, s'il faut tracer les points non définis (NaN ou inf)

            )
# Out:
# c:\Users\Thaz\anaconda3\lib\site-packages\matplotlib\collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#Scatter + Histo avec un set aléatoire , en OO

#délimiter la figure
fig = plt.figure(figsize=(6,6))

''' on va définir un "gridspec" de 2x2 (on a trois graph dans un tableau et une case vide)
il est possible de définir le ratio des axes selon les besoins, voir les params de la méthode addgridspec'''
my_grid = fig.add_gridspec(2, 2, #taille de la maille
                           width_ratios = (4, 1),
                           height_ratios = (1, 4),#ratio des axes
                            # left = 0.2,
                            # right = 0.8, 
                            # bottom = 0.2,
                            # top = 0.8, #fractions de la figure d'origine, jouer avec pour voir, left > right, top > bottom, marges avec le bord
                            wspace = 0.2,
                            hspace = 0.2, #marges entre les graphes
                            )

#création des axes

axe = fig.add_subplot(my_grid[1,0]) # premier graph (scatter), dans la seconde ligne premier colonne du gridspec
axe_histx = fig.add_subplot(my_grid[0,0], sharex = axe) #etc 
axe_histy = fig.add_subplot(my_grid[1,1], sharey = axe)

#on trace le scatter
axe.scatter(data_x, data_y)
#on ajoute les histo
axe_histx.hist(data_x, bins = 50, density= True)
axe_histy.hist(data_y, bins = 50, density = True, orientation='horizontal')
# les abcisses des histos sont redondantes, on peut les enlever : 
axe_histx.tick_params(axis='x', labelbottom = False)
axe_histy.tick_params(axis='y', labelleft = False)

# %%
#si on essaie de rajouter une catégorie à deux jeux de données : 
import matplotlib
taille_h = np.random.randint(150,190,100)
masse_h = np.random.randint(60,120,100)
taille_f = np.random.randint(140,175,100)
masse_f = np.random.randint(40,90,100)
couleurs = np.random.randint(0,2, 100)
fig = plt.figure(figsize=(4,4))

my_grid = fig.add_gridspec(2, 2, 
                           width_ratios = (4, 1),
                           height_ratios = (1, 4),
                            wspace = 0.2,
                            hspace = 0.2,
                           )

axe = fig.add_subplot(my_grid[1,0]) 
axe_histx = fig.add_subplot(my_grid[0,0], sharex = axe) 
axe_histy = fig.add_subplot(my_grid[1,1], sharey = axe)

#pour colorier le scatter et les histo de la même façon
type_couleur= [matplotlib.cm.Accent(0) , matplotlib.cm.Accent(1)]

axe.scatter(x= taille_f, y= masse_f, color = type_couleur[1], label = 'Femme')
axe.scatter(x= taille_h, y= masse_h, color = type_couleur[0], label= 'Hommes')

axe.set_xlabel('Taille (cm)')
axe.set_ylabel('Poids (kg)')

axe_histx.hist([taille_h, taille_f] , color = type_couleur, bins = 50, density= True)

axe_histy.hist([masse_h, masse_f] , color = type_couleur, bins = 50, density = True, orientation='horizontal')

axe_histx.tick_params(axis='x', labelbottom = False)
axe_histy.tick_params(axis='y', labelleft = False)
axe.legend()

# %%
plt.figure(figsize=(6,6))
fig, ax = plt.subplots(1)
ax.set_aspect(1)
def cercle(r):
    thetha = np.linspace(0, 2*np.pi,100)
    x = r * np.cos(thetha)
    y = r * np.sin(thetha)
    return x, y
    
for i in range(1,5):
    x , y = cercle(i)
    ax.plot(x,y)

# %%
plt.figure(figsize=(6,6))
fig, ax = plt.subplots(1)
ax.set_aspect(1)
def cercle_modif(r):
    n_points = 500
    thetha = np.linspace(0, 2*np.pi, n_points)
    modif = np.random.randint(1, 3, n_points)
    x =  -modif/100 +  (r+(np.sin(modif/1.1))) * np.cos(thetha)
    y = +modif/10 + (r+(np.sin(modif))) * np.sin(thetha)
    ax.plot(x,y)

for i in range(1):
    cercle_modif(i)
